# %%
import sympy as sp
import pandas as pd
import numpy as np
from IPython.display import display, HTML, Math

def newton_raphson_ejemplo22(x0_val=1700.0, tol=1e-6, max_iter=100):
    # 1. Variable simbólica
    x = sp.Symbol('x')

    # 2. Definición de la ecuación de balance de energía
    f_expr = -4.5e6 + 110*(94502) - 110*(10.2)*(x-298) - 31.07*(7.3)*(x-298) \
             - 700.1*(7.9)*(x-298) + 90*(68320) - 90*(18)*(373-298) - 90*(10600) - 90*(8.3)*(x-373)

    df_expr = sp.diff(f_expr, x)

    # Encabezado visual
    html_header = """
    <div style="background-color: #f8f9fa; border-left: 5px solid #007bff; padding: 15px; margin-bottom: 15px; border-radius: 4px;">
        <h2 style="color: #007bff; margin-top: 0; font-family: sans-serif;">Método de Newton-Raphson</h2>
        <p style="font-size: 15px; font-family: sans-serif; color: #333;">
            Ejemplo 22: Balance de Energía
        </p>
    </div>
    """
    display(HTML(html_header))

    display(Math(rf"\mathbf{{Función\ evaluada:}}\quad f(x) = -8095.611 x + 14114704.90 = 0"))
    display(Math(rf"\mathbf{{Derivada\ analítica:}}\quad f'(x) = -8095.611"))

    # Conversión a funciones numéricas
    f_num = sp.lambdify(x, f_expr, modules=['numpy'])
    df_num = sp.lambdify(x, df_expr, modules=['numpy'])

    # Algoritmo de Newton-Raphson
    iteraciones = []
    x_n = float(x0_val)

    for n in range(max_iter):
        fx = float(f_num(x_n))
        dfx = float(df_num(x_n))

        error = np.nan if n == 0 else abs(x_n - x_prev)

        iteraciones.append({
            'n': n,
            'x_n': x_n,
            'f(x_n)': fx,
            'f\'(x_n)': dfx,
            'Error': error
        })

        if n > 0 and error < tol:
            break

        x_prev = x_n
        x_n = x_n - (fx / dfx)

    df_res = pd.DataFrame(iteraciones)

    # Formato visual
    df_res_styled = df_res.copy()
    df_res_styled.columns = [
        '<i>n</i>',
        '<i>x<sub>n</sub></i>',
        '<i>f(x<sub>n</sub>)</i>',
        '<i>f \'(x<sub>n</sub>)</i>',
        '<i>Error (E<sub>n</sub>)</i>'
    ]

    tabla_styled = df_res_styled.style.format({
        '<i>x<sub>n</sub></i>': '{:.6f}',
        '<i>f(x<sub>n</sub>)</i>': '{:.6e}',
        '<i>f \'(x<sub>n</sub>)</i>': '{:.6e}',
        '<i>Error (E<sub>n</sub>)</i>': lambda v: '—' if np.isnan(v) else f'{v:.6f}'
    }).set_table_styles([
        {'selector': 'th', 'props': [
            ('background-color', '#007bff'),
            ('color', '#ffffff'),
            ('font-family', 'sans-serif'),
            ('font-size', '14px'),
            ('text-align', 'center'),
            ('padding', '10px')
        ]},
        {'selector': 'td', 'props': [
            ('text-align', 'center'),
            ('font-family', 'monospace'),
            ('font-size', '13px'),
            ('padding', '8px')
        ]}
    ]).hide(axis='index')

    display(HTML("<h3 style='font-family: sans-serif; color: #333;'>Tabla de Iteraciones</h3>"))
    display(tabla_styled)

    raiz_final = df_res.iloc[-1]['x_n']
    num_iter = int(df_res.iloc[-1]['n'])

    display(HTML(f"""
    <div style="background-color: #d4edda; color: #155724; padding: 12px; border-radius: 5px; margin-top: 15px; border: 1px solid #c3e6cb; font-family: sans-serif;">
        <strong>Convergencia alcanzada:</strong> Solución <i>T</i> &approx; <code>{raiz_final:.6f} K</code> (&approx; <code>{raiz_final:.1f} K</code>) en <strong>{num_iter}</strong> iteraciones.
    </div>
    """))

# Ejecución en Colab
newton_raphson_ejemplo22(x0_val=1700.0, tol=1e-6)
# Out:
#     <div style="background-color: #f8f9fa; border-left: 5px solid #007bff; padding: 15px; margin-bottom: 15px; border-radius: 4px;">
#         <h2 style="color: #007bff; margin-top: 0; font-family: sans-serif;">Método de Newton-Raphson</h2>
#         <p style="font-size: 15px; font-family: sans-serif; color: #333;">
#             Ejemplo 22: Balance de Energía
#         </p>
#     </div>
# $\displaystyle \mathbf{Función\ evaluada:}\quad f(x) = -8095.611 x + 14114704.90 = 0$
# $\displaystyle \mathbf{Derivada\ analítica:}\quad f'(x) = -8095.611$
# <h3 style='font-family: sans-serif; color: #333;'>Tabla de Iteraciones</h3>
# <style type="text/css">
# #T_2a8e9 th {
#   background-color: #007bff;
#   color: #ffffff;
#   font-family: sans-serif;
#   font-size: 14px;
#   text-align: center;
#   padding: 10px;
# }
# #T_2a8e9 td {
#   text-align: center;
#   font-family: monospace;
#   font-size: 13px;
#   padding: 8px;
# }
# </style>
# <table id="T_2a8e9" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_2a8e9_level0_col0" class="col_heading level0 col0" ><i>n</i></th>
#       <th id="T_2a8e9_level0_col1" class="col_heading level0 col1" ><i>x<sub>n</sub></i></th>
#       <th id="T_2a8e9_level0_col2" class="col_heading level0 col2" ><i>f(x<sub>n</sub>)</i></th>
#       <th id="T_2a8e9_level0_col3" class="col_heading level0 col3" ><i>f '(x<sub>n</sub>)</i></th>
#       <th id="T_2a8e9_level0_col4" class="col_heading level0 col4" ><i>Error (E<sub>n</sub>)</i></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2a8e9_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_2a8e9_row0_col1" class="data row0 col1" >1700.000000</td>
#       <td id="T_2a8e9_row0_col2" class="data row0 col2" >3.320504e+05</td>
#       <td id="T_2a8e9_row0_col3" class="data row0 col3" >-7.626601e+03</td>
#       <td id="T_2a8e9_row0_col4" class="data row0 col4" >—</td>
#     </tr>
#     <tr>
#       <td id="T_2a8e9_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_2a8e9_row1_col1" class="data row1 col1" >1743.538452</td>
#       <td id="T_2a8e9_row1_col2" class="data row1 col2" >0.000000e+00</td>
#       <td id="T_2a8e9_row1_col3" class="data row1 col3" >-7.626601e+03</td>
#       <td id="T_2a8e9_row1_col4" class="data row1 col4" >43.538452</td>
#     </tr>
#     <tr>
#       <td id="T_2a8e9_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_2a8e9_row2_col1" class="data row2 col1" >1743.538452</td>
#       <td id="T_2a8e9_row2_col2" class="data row2 col2" >0.000000e+00</td>
#       <td id="T_2a8e9_row2_col3" class="data row2 col3" >-7.626601e+03</td>
#       <td id="T_2a8e9_row2_col4" class="data row2 col4" >0.000000</td>
#     </tr>
#   </tbody>
# </table>
#     <div style="background-color: #d4edda; color: #155724; padding: 12px; border-radius: 5px; margin-top: 15px; border: 1px solid #c3e6cb; font-family: sans-serif;">
#         <strong>Convergencia alcanzada:</strong> Solución <i>T</i> &approx; <code>1743.538452 K</code> (&approx; <code>1743.5 K</code>) en <strong>2</strong> iteraciones.
#     </div>
