# %%
import sympy as sp
import pandas as pd
import numpy as np
from IPython.display import display, HTML, Math

def newton_raphson_ejemplo21(x0_val=1900.0, tol=1e-6, max_iter=100):
    # 1. Variable simbólica
    x = sp.Symbol('x')

    # 2. Definición de la ecuación
    f_expr = -2.2575e-8 * x**4 + 6.823e-5 * x**3 - 2.9925e-3 * x**2 + 377.2 * x - 916474.9
    df_expr = sp.diff(f_expr, x)

    # Encabezado visual
    html_header = """
    <div style="background-color: #f8f9fa; border-left: 5px solid #007bff; padding: 15px; margin-bottom: 15px; border-radius: 4px;">
        <h2 style="color: #007bff; margin-top: 0; font-family: sans-serif;">Método de Newton-Raphson</h2>
        <p style="font-size: 15px; font-family: sans-serif; color: #333;">
            Ejemplo 21: Polinomio de Grado 4
        </p>
    </div>
    """
    display(HTML(html_header))

    display(Math(rf"\mathbf{{Función\ evaluada:}}\quad f(x) = -2.2575 \times 10^{{-8}} x^4 + 6.823 \times 10^{{-5}} x^3 - 2.9925 \times 10^{{-3}} x^2 + 377.2 x - 916474.9 = 0"))
    display(Math(rf"\mathbf{{Derivada\ analítica:}}\quad f'(x) = -9.03 \times 10^{{-8}} x^3 + 2.0469 \times 10^{{-4}} x^2 - 5.985 \times 10^{{-3}} x + 377.2"))

    # Conversión a funciones numéricas
    f_num = sp.lambdify(x, f_expr, modules=['numpy'])
    df_num = sp.lambdify(x, df_expr, modules=['numpy'])

    # Algoritmo de Newton-Raphson
    iteraciones = []
    x_n = float(x0_val)

    for n in range(max_iter):
        fx = float(f_num(x_n))
        dfx = float(df_num(x_n))

        error = np.nan if n == 0 else abs(x_n - x_prev)

        iteraciones.append({
            'n': n,
            'x_n': x_n,
            'f(x_n)': fx,
            'f\'(x_n)': dfx,
            'Error': error
        })

        if n > 0 and error < tol:
            break

        x_prev = x_n
        x_n = x_n - (fx / dfx)

    df_res = pd.DataFrame(iteraciones)

    # Formato visual
    df_res_styled = df_res.copy()
    df_res_styled.columns = [
        '<i>n</i>',
        '<i>x<sub>n</sub></i>',
        '<i>f(x<sub>n</sub>)</i>',
        '<i>f \'(x<sub>n</sub>)</i>',
        '<i>Error (E<sub>n</sub>)</i>'
    ]

    tabla_styled = df_res_styled.style.format({
        '<i>x<sub>n</sub></i>': '{:.6f}',
        '<i>f(x<sub>n</sub>)</i>': '{:.6e}',
        '<i>f \'(x<sub>n</sub>)</i>': '{:.6e}',
        '<i>Error (E<sub>n</sub>)</i>': lambda v: '—' if np.isnan(v) else f'{v:.6f}'
    }).set_table_styles([
        {'selector': 'th', 'props': [
            ('background-color', '#007bff'),
            ('color', '#ffffff'),
            ('font-family', 'sans-serif'),
            ('font-size', '14px'),
            ('text-align', 'center'),
            ('padding', '10px')
        ]},
        {'selector': 'td', 'props': [
            ('text-align', 'center'),
            ('font-family', 'monospace'),
            ('font-size', '13px'),
            ('padding', '8px')
        ]}
    ]).hide(axis='index')

    display(HTML("<h3 style='font-family: sans-serif; color: #333;'>Tabla de Iteraciones</h3>"))
    display(tabla_styled)

    raiz_final = df_res.iloc[-1]['x_n']
    num_iter = int(df_res.iloc[-1]['n'])

    display(HTML(f"""
    <div style="background-color: #d4edda; color: #155724; padding: 12px; border-radius: 5px; margin-top: 15px; border: 1px solid #c3e6cb; font-family: sans-serif;">
        <strong>Convergencia alcanzada:</strong> Solución <i>x</i> &approx; <code>{raiz_final:.6f}</code> (&approx; <code>{raiz_final:.1f}</code>) en <strong>{num_iter}</strong> iteraciones.
    </div>
    """))

# Ejecución en Colab
newton_raphson_ejemplo21(x0_val=1900.0, tol=1e-6)
# Out:
#     <div style="background-color: #f8f9fa; border-left: 5px solid #007bff; padding: 15px; margin-bottom: 15px; border-radius: 4px;">
#         <h2 style="color: #007bff; margin-top: 0; font-family: sans-serif;">Método de Newton-Raphson</h2>
#         <p style="font-size: 15px; font-family: sans-serif; color: #333;">
#             Ejemplo 21: Polinomio de Grado 4
#         </p>
#     </div>
# $\displaystyle \mathbf{Función\ evaluada:}\quad f(x) = -2.2575 \times 10^{-8} x^4 + 6.823 \times 10^{-5} x^3 - 2.9925 \times 10^{-3} x^2 + 377.2 x - 916474.9 = 0$
# $\displaystyle \mathbf{Derivada\ analítica:}\quad f'(x) = -9.03 \times 10^{-8} x^3 + 2.0469 \times 10^{-4} x^2 - 5.985 \times 10^{-3} x + 377.2$
# <h3 style='font-family: sans-serif; color: #333;'>Tabla de Iteraciones</h3>
# <style type="text/css">
# #T_13bea th {
#   background-color: #007bff;
#   color: #ffffff;
#   font-family: sans-serif;
#   font-size: 14px;
#   text-align: center;
#   padding: 10px;
# }
# #T_13bea td {
#   text-align: center;
#   font-family: monospace;
#   font-size: 13px;
#   padding: 8px;
# }
# </style>
# <table id="T_13bea" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_13bea_level0_col0" class="col_heading level0 col0" ><i>n</i></th>
#       <th id="T_13bea_level0_col1" class="col_heading level0 col1" ><i>x<sub>n</sub></i></th>
#       <th id="T_13bea_level0_col2" class="col_heading level0 col2" ><i>f(x<sub>n</sub>)</i></th>
#       <th id="T_13bea_level0_col3" class="col_heading level0 col3" ><i>f '(x<sub>n</sub>)</i></th>
#       <th id="T_13bea_level0_col4" class="col_heading level0 col4" ><i>Error (E<sub>n</sub>)</i></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_13bea_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_13bea_row0_col1" class="data row0 col1" >1900.000000</td>
#       <td id="T_13bea_row0_col2" class="data row0 col2" >-3.680791e+04</td>
#       <td id="T_13bea_row0_col3" class="data row0 col3" >4.853917e+02</td>
#       <td id="T_13bea_row0_col4" class="data row0 col4" >—</td>
#     </tr>
#     <tr>
#       <td id="T_13bea_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_13bea_row1_col1" class="data row1 col1" >1975.831359</td>
#       <td id="T_13bea_row1_col2" class="data row1 col2" >-6.384217e+02</td>
#       <td id="T_13bea_row1_col3" class="data row1 col3" >4.679398e+02</td>
#       <td id="T_13bea_row1_col4" class="data row1 col4" >75.831359</td>
#     </tr>
#     <tr>
#       <td id="T_13bea_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_13bea_row2_col1" class="data row2 col1" >1977.195684</td>
#       <td id="T_13bea_row2_col2" class="data row2 col2" >-2.373158e-01</td>
#       <td id="T_13bea_row2_col3" class="data row2 col3" >4.675917e+02</td>
#       <td id="T_13bea_row2_col4" class="data row2 col4" >1.364324</td>
#     </tr>
#     <tr>
#       <td id="T_13bea_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_13bea_row3_col1" class="data row3 col1" >1977.196191</td>
#       <td id="T_13bea_row3_col2" class="data row3 col2" >-3.282912e-08</td>
#       <td id="T_13bea_row3_col3" class="data row3 col3" >4.675916e+02</td>
#       <td id="T_13bea_row3_col4" class="data row3 col4" >0.000508</td>
#     </tr>
#     <tr>
#       <td id="T_13bea_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_13bea_row4_col1" class="data row4 col1" >1977.196191</td>
#       <td id="T_13bea_row4_col2" class="data row4 col2" >0.000000e+00</td>
#       <td id="T_13bea_row4_col3" class="data row4 col3" >4.675916e+02</td>
#       <td id="T_13bea_row4_col4" class="data row4 col4" >0.000000</td>
#     </tr>
#   </tbody>
# </table>
#     <div style="background-color: #d4edda; color: #155724; padding: 12px; border-radius: 5px; margin-top: 15px; border: 1px solid #c3e6cb; font-family: sans-serif;">
#         <strong>Convergencia alcanzada:</strong> Solución <i>x</i> &approx; <code>1977.196191</code> (&approx; <code>1977.2</code>) en <strong>4</strong> iteraciones.
#     </div>
